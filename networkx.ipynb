# %%
import networkx as nx
import pprint as pp

G = nx.Graph()
G.add_edges_from([(1, 2), (1, 3)])
G.edges
# Out:
# EdgeView([(1, 2), (1, 3)])

# %%
G = nx.sedgewick_maze_graph()
nx.draw(G, with_labels=True, font_color="white")

# nx.to_pandas_adjacency(G)
# nx.to_pandas_edgelist(G)
# pp.pprint(nx.shortest_path(G))
