# %%
from bokeh.plotting import figure, show, output_notebook
import numpy as np
import matplotlib.pyplot as plt

output_notebook()

np.random.seed(42)

fig = figure(y_range=(0.56, 0.86), width=800, height=600)

n = x
se = np.sqrt(p*(1-p)/n)
upper = p + 1.645 * se
lower = p - 1.645 * se
fig.varea(x, lower, upper, alpha=0.2)
last_y = np.empty(100)

num_escaped = 0
for i in range(100):
    p = 0.71
    x = np.ones((10, 100)).sum(axis=0).cumsum()
    y = np.random.binomial(1, p, 1000).reshape(10, 100).sum(axis=0).cumsum()/x
    escaped = True if np.any(y > upper) or np.any(y < lower) else False
    fig.line(x, y, color="red" if escaped else "blue")
    if escaped: num_escaped += 1
    last_y[i] = y[-1]
    
fig.output_backend = "svg"
show(fig)
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="359177">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ba0b7707-0e02-45f8-972a-69a76ed37884" data-root-id="359178"></div>

# %%
np.mean((last_y > upper) | (last_y < lower))
# Out:
# 0.06

# %%
num_escaped/100
# Out:
# 0.55
